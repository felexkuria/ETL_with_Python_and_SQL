# %%
import pandas as PD

# %%
data=PD.Series([1,2,3,4.5])

# %%
print(data)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.5
# dtype: float64

# %%
data={"Name":["Mwangi","John","Muthoni"],"Age":[23,23,45]}

# %%
df=PD.DataFrame(data)
